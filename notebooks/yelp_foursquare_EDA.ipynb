# %%
import requests

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
#get data from the FS API
def get_venues_fs(latitude, longitude, radius, api_key, categories):
    """
    Get venues from foursquare with a specified place type and coordinates.
    Args:
        latitude (float): latitude for query (must be combined with longitude)
        longitude (float): longitude for query (must be combined with latitude)
        api_key (str): foursquare API to use for query
        categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. Separate ids with commas
    
    Returns:
        response: response object from the requests library.
    """
    # create the URL
    url = "https://api.foursquare.com/v3/places/search"
    # create the parameters
    params = {
        "ll" : f"{latitude},{longitude}",
        "radius" : radius,
        "categories" : categories,

    }
    # create the headers
    headers = {
        "accept": "application/json",
        "Authorization": api_key
        }
    # make the request
    resp = requests.get(url=url, params=params, headers=headers)
    # return the response
    return resp

# %%
test=get_venues_fs(43.2557,-79.8711, 1000, 'fsq3kU64qnhREToz54Pt8yZpeE8fglH4Ui3QleVfrawVEIA=', None)

# %%
print(test)
# Out:
# <Response [200]>

# %%
test.json()
# Out:
# {'results': [{'fsq_id': '4d93318162ad5481a9ec7b4b',
#    'categories': [{'id': 10027,
#      'name': 'Museum',
#      'short_name': 'Museum',
#      'plural_name': 'Museums',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 172,
#    'geocodes': {'main': {'latitude': 43.254593, 'longitude': -79.87211},
#     'roof': {'latitude': 43.254596, 'longitude': -79.871991}},
#    'link': '/v3/places/4d93318162ad5481a9ec7b4b',
#    'location': {'address': '41 Jackson St W',
#     'country': 'CA',
#     'formatted_address': '41 Jackson St W, Hamilton ON L8P 1L3',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1L3',
#     'region': 'ON'},
#    'name': 'Whitehern Historic House and Garden',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '50a19225e4b035e940520491',
#    'categories': [{'id': 13305,
#      'name': 'Burrito Restaurant',
#      'short_name': 'Burritos',
#      'plural_name': 'Burrito Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 320,
#    'geocodes': {'main': {'latitude': 43.255691, 'longitude': -79.867215},
#     'roof': {'latitude': 43.255691, 'longitude': -79.867215}},
#    'link': '/v3/places/50a19225e4b035e940520491',
#    'location': {'address': '66 King St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '66 King St E, Hamilton ON L8N 1A6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1A6',
#     'region': 'ON'},
#    'name': 'Burrito Boyz',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '55de230f498eecf46f6652a2',
#    'categories': [{'id': 13306,
#      'name': 'Taco Restaurant',
#      'short_name': 'Tacos',
#      'plural_name': 'Taco Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 343,
#    'geocodes': {'drop_off': {'latitude': 43.257143, 'longitude': -79.86724},
#     'main': {'latitude': 43.257258, 'longitude': -79.867202},
#     'roof': {'latitude': 43.257258, 'longitude': -79.867202}},
#    'link': '/v3/places/55de230f498eecf46f6652a2',
#    'location': {'address': '41 King William St',
#     'country': 'CA',
#     'cross_street': 'Hughson',
#     'formatted_address': '41 King William St (Hughson), Hamilton ON L8R 1A2',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 1A2',
#     'region': 'ON'},
#    'name': 'The Mule',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b628f4bf964a5205a4b2ae3',
#    'categories': [{'id': 17065,
#      'name': 'Farmers Market',
#      'short_name': 'Farmers Market',
#      'plural_name': 'Farmers Markets',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 395,
#    'geocodes': {'main': {'latitude': 43.259041, 'longitude': -79.870193},
#     'roof': {'latitude': 43.259041, 'longitude': -79.870193}},
#    'link': '/v3/places/4b628f4bf964a5205a4b2ae3',
#    'location': {'address': '55 York Blvd',
#     'country': 'CA',
#     'cross_street': 'at James',
#     'formatted_address': '55 York Blvd (at James), Hamilton ON L8R 3K1',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 3K1',
#     'region': 'ON'},
#    'name': "Hamilton Farmers' Market",
#    'related_places': {'children': [{'fsq_id': '5d7bd06979bb820008173f0e',
#       'categories': [{'id': 13026,
#         'name': 'BBQ Joint',
#         'short_name': 'BBQ',
#         'plural_name': 'BBQ Joints',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#          'suffix': '.png'}}],
#       'name': 'Saltlick Smokehouse'},
#      {'fsq_id': '5688080b498ef6dccacdba77',
#       'categories': [{'id': 13145,
#         'name': 'Fast Food Restaurant',
#         'short_name': 'Fast Food',
#         'plural_name': 'Fast Food Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#          'suffix': '.png'}},
#        {'id': 13272,
#         'name': 'Ramen Restaurant',
#         'short_name': 'Ramen',
#         'plural_name': 'Ramen Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#          'suffix': '.png'}}],
#       'name': 'Eat Industries'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '51d2d6a9498e483fe7634ebf',
#    'categories': [{'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 403,
#    'geocodes': {'drop_off': {'latitude': 43.256701, 'longitude': -79.86911},
#     'main': {'latitude': 43.25672, 'longitude': -79.869105}},
#    'link': '/v3/places/51d2d6a9498e483fe7634ebf',
#    'location': {'address': '2 King St W',
#     'country': 'CA',
#     'cross_street': 'in Jackson Square',
#     'formatted_address': '2 King St W (in Jackson Square), Hamilton ON L8P 1A1',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1A1',
#     'region': 'ON'},
#    'name': 'Nations Fresh Food Market',
#    'related_places': {'parent': {'fsq_id': '4b628e9ff964a520474b2ae3',
#      'categories': [{'id': 17114,
#        'name': 'Shopping Mall',
#        'short_name': 'Mall',
#        'plural_name': 'Shopping Malls',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#         'suffix': '.png'}}],
#      'name': 'Jackson Square'}},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b5e5923f964a520b78a29e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13031,
#      'name': 'Burger Joint',
#      'short_name': 'Burgers',
#      'plural_name': 'Burger Joints',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}},
#     {'id': 13338,
#      'name': 'Seafood Restaurant',
#      'short_name': 'Seafood',
#      'plural_name': 'Seafood Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 409,
#    'geocodes': {'drop_off': {'latitude': 43.251943, 'longitude': -79.870017},
#     'main': {'latitude': 43.252066, 'longitude': -79.869987},
#     'roof': {'latitude': 43.252066, 'longitude': -79.869987}},
#    'link': '/v3/places/4b5e5923f964a520b78a29e3',
#    'location': {'address': '23 Augusta St',
#     'country': 'CA',
#     'cross_street': 'Hughson St.',
#     'formatted_address': '23 Augusta St (Hughson St.), Hamilton ON L8N 1P6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P6',
#     'region': 'ON'},
#    'name': 'The Ship',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b01f834f964a520e64622e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 420,
#    'geocodes': {'drop_off': {'latitude': 43.252037, 'longitude': -79.870397},
#     'main': {'latitude': 43.25192, 'longitude': -79.870426},
#     'roof': {'latitude': 43.25192, 'longitude': -79.870426}},
#    'link': '/v3/places/4b01f834f964a520e64622e3',
#    'location': {'address': '20 Augusta St',
#     'country': 'CA',
#     'cross_street': 'James St.',
#     'formatted_address': '20 Augusta St (James St.), Hamilton ON L8N 1P7',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P7',
#     'region': 'ON'},
#    'name': 'The Pheasant Plucker',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b6a4bc5f964a52024d12be3',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13134,
#      'name': 'Comfort Food Restaurant',
#      'short_name': 'Comfort Food',
#      'plural_name': 'Comfort Food Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 436,
#    'geocodes': {'main': {'latitude': 43.251462, 'longitude': -79.872017},
#     'roof': {'latitude': 43.251462, 'longitude': -79.872017}},
#    'link': '/v3/places/4b6a4bc5f964a52024d12be3',
#    'location': {'address': '1 Duke St',
#     'country': 'CA',
#     'cross_street': 'at James St. South',
#     'formatted_address': '1 Duke St (at James St. South), Hamilton ON L8P 1W9',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1W9',
#     'region': 'ON'},
#    'name': 'One Duke Restaurant & Lounge',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '591534a12aff31013acefff6',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13029,
#      'name': 'Brewery',
#      'short_name': 'Brewery',
#      'plural_name': 'Breweries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.25949, 'longitude': -79.867997},
#     'roof': {'latitude': 43.25949, 'longitude': -79.867997}},
#    'link': '/v3/places/591534a12aff31013acefff6',
#    'location': {'address': '107 James St N',
#     'country': 'CA',
#     'cross_street': 'at York Blvd',
#     'formatted_address': '107 James St N (at York Blvd), Hamilton ON L8R 2K6',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 2K6',
#     'region': 'ON'},
#    'name': 'Merit Brewing',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '56773b87498ee8858831bb66',
#    'categories': [{'id': 13033,
#      'name': 'Bubble Tea Shop',
#      'short_name': 'Bubble Tea',
#      'plural_name': 'Bubble Tea Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'}},
#     {'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 427,
#    'geocodes': {'main': {'latitude': 43.254333, 'longitude': -79.865966},
#     'roof': {'latitude': 43.254333, 'longitude': -79.865966}},
#    'link': '/v3/places/56773b87498ee8858831bb66',
#    'location': {'address': '96 Main St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '96 Main St E, Hamilton ON L8N 1G3',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1G3',
#     'region': 'ON'},
#    'name': 'Coco Fresh Tea & Juice',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.2557,
#      'longitude': -79.8711},
#     'radius': 1000}}}}

# %%
import pandas as pd

# %%
available_bikes=pd.read_csv('..\\data\\available_bikes.csv')

# %%
available_bikes
# Out:
#               Station Name   Latitude  Longitude  Bikes Available
# 0             Hess at king  43.259126 -79.877212                8
# 1            Bayfront Park  43.269288 -79.871327                9
# 2          Bay at Strachan  43.267859 -79.867923                9
# 3          Bay at Mulberry  43.263198 -79.871803                4
# 4                City Hall  43.256132 -79.874499                2
# ..                     ...        ...        ...              ...
# 139  King William at James  43.257635 -79.868487                1
# 140        Westdale Aviary  43.264869 -79.907480                6
# 141       Hunter GO Centre  43.253330 -79.869533                3
# 142       Westdale Village  43.262015 -79.905088               11
# 143       Cannon at Ottawa  43.247565 -79.818050                5
#
# [144 rows x 4 columns]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests

url = "https://api.foursquare.com/v3/places/search?ll=43.2557%2C-79.8711"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3kU64qnhREToz54Pt8yZpeE8fglH4Ui3QleVfrawVEIA="
}

response = requests.get(url, headers=headers)

print(response.text)

# Define category IDs for bike-related venues
bike_rental_category_id = '4e4c9077bd41f78e849722f9'  # Bike rental / bike shop category ID
# Out:
# {"results":[{"fsq_id":"4b01f834f964a520e64622e3","categories":[{"id":13018,"name":"Pub","short_name":"Pub","plural_name":"Pubs","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13068,"name":"American Restaurant","short_name":"American","plural_name":"American Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}},{"id":13236,"name":"Italian Restaurant","short_name":"Italian","plural_name":"Italian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":420,"geocodes":{"drop_off":{"latitude":43.252037,"longitude":-79.870397},"main":{"latitude":43.25192,"longitude":-79.870426},"roof":{"latitude":43.25192,"longitude":-79.870426}},"link":"/v3/places/4b01f834f964a520e64622e3","location":{"address":"20 Augusta St","country":"CA","cross_street":"James St.","formatted_address":"20 Augusta St (James St.), Hamilton ON L8N 1P7","locality":"Hamilton","postcode":"L8N 1P7","region":"ON"},"name":"The Pheasant Plucker","related_places":{},"timezone":"America/Toronto"},{"fsq_id":"4b5e5923f964a520b78a29e3","categories":[{"id":13018,"name":"Pub","short_name":"Pub","plural_name":"Pubs","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13031,"name":"Burger Joint","short_name":"Burgers","plural_name":"Burger Joints","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}},{"id":13338,"name":"Seafood Restaurant","short_name":"Seafood","plural_name":"Seafood Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/seafood_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":409,"geocodes":{"drop_off":{"latitude":43.251943,"longitude":-79.870017},"main":{"latitude":43.252066,"longitude":-79.869987},"roof":{"latitude":43.252066,"longitude":-79.869987}},"link":"/v3/places/4b5e5923f964a520b78a29e3","location":{"address":"23 Augusta St","country":"CA","cross_street":"Hughson St.","formatted_address":"23 Augusta St (Hughson St.), Hamilton ON L8N 1P6","locality":"Hamilton","postcode":"L8N 1P6","region":"ON"},"name":"The Ship","related_places":{},"timezone":"America/Toronto"},{"fsq_id":"5036724be4b001c520354587","categories":[{"id":13034,"name":"Café","short_name":"Café","plural_name":"Cafés","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"Unsure","distance":922,"geocodes":{"drop_off":{"latitude":43.253761,"longitude":-79.860001},"main":{"latitude":43.253614,"longitude":-79.860049},"roof":{"latitude":43.253614,"longitude":-79.860049}},"link":"/v3/places/5036724be4b001c520354587","location":{"address":"312 King St E","country":"CA","cross_street":"Wellington St","formatted_address":"312 King St E (Wellington St), Hamilton ON L8N 1C2","locality":"Hamilton","postcode":"L8N 1C2","region":"ON"},"name":"Cafe Oranje","related_places":{},"timezone":"America/Toronto"},{"fsq_id":"4b817446f964a5201da730e3","categories":[{"id":16032,"name":"Park","short_name":"Park","plural_name":"Parks","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":1508,"geocodes":{"main":{"latitude":43.267592,"longitude":-79.868115},"roof":{"latitude":43.267592,"longitude":-79.868115}},"link":"/v3/places/4b817446f964a5201da730e3","location":{"address":"325 Bay St N","country":"CA","cross_street":"at Strachan St W","formatted_address":"325 Bay St N (at Strachan St W) ...

# %%
# Function to query Foursquare API for venues near a given location
def get_nearby_venues(ll, radius, category_id):
    params = {
        # 'client_id': CLIENT_ID,
        # 'client_secret': CLIENT_SECRET,
        # 'v': VERSION,
        'll': ll,
        'radius': radius,
        'categoryId': category_id
    }
    headers = {
    "accept": "application/json",
    "Authorization": "fsq3kU64qnhREToz54Pt8yZpeE8fglH4Ui3QleVfrawVEIA="
}
    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
       # return response.json()['response']['venues']
        return response.json()
    else:
        print(f'Error: {response.status_code} - {response.text}')
        return None

# %%
test=get_nearby_venues ((43.2557,-79.8711), 1000, None)

# %%
test
# Out:
# {'results': [{'fsq_id': '4d93318162ad5481a9ec7b4b',
#    'categories': [{'id': 10027,
#      'name': 'Museum',
#      'short_name': 'Museum',
#      'plural_name': 'Museums',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 172,
#    'geocodes': {'main': {'latitude': 43.254593, 'longitude': -79.87211},
#     'roof': {'latitude': 43.254596, 'longitude': -79.871991}},
#    'link': '/v3/places/4d93318162ad5481a9ec7b4b',
#    'location': {'address': '41 Jackson St W',
#     'country': 'CA',
#     'formatted_address': '41 Jackson St W, Hamilton ON L8P 1L3',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1L3',
#     'region': 'ON'},
#    'name': 'Whitehern Historic House and Garden',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '50a19225e4b035e940520491',
#    'categories': [{'id': 13305,
#      'name': 'Burrito Restaurant',
#      'short_name': 'Burritos',
#      'plural_name': 'Burrito Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 320,
#    'geocodes': {'main': {'latitude': 43.255691, 'longitude': -79.867215},
#     'roof': {'latitude': 43.255691, 'longitude': -79.867215}},
#    'link': '/v3/places/50a19225e4b035e940520491',
#    'location': {'address': '66 King St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '66 King St E, Hamilton ON L8N 1A6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1A6',
#     'region': 'ON'},
#    'name': 'Burrito Boyz',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '55de230f498eecf46f6652a2',
#    'categories': [{'id': 13306,
#      'name': 'Taco Restaurant',
#      'short_name': 'Tacos',
#      'plural_name': 'Taco Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 343,
#    'geocodes': {'drop_off': {'latitude': 43.257143, 'longitude': -79.86724},
#     'main': {'latitude': 43.257258, 'longitude': -79.867202},
#     'roof': {'latitude': 43.257258, 'longitude': -79.867202}},
#    'link': '/v3/places/55de230f498eecf46f6652a2',
#    'location': {'address': '41 King William St',
#     'country': 'CA',
#     'cross_street': 'Hughson',
#     'formatted_address': '41 King William St (Hughson), Hamilton ON L8R 1A2',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 1A2',
#     'region': 'ON'},
#    'name': 'The Mule',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b628f4bf964a5205a4b2ae3',
#    'categories': [{'id': 17065,
#      'name': 'Farmers Market',
#      'short_name': 'Farmers Market',
#      'plural_name': 'Farmers Markets',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 395,
#    'geocodes': {'main': {'latitude': 43.259041, 'longitude': -79.870193},
#     'roof': {'latitude': 43.259041, 'longitude': -79.870193}},
#    'link': '/v3/places/4b628f4bf964a5205a4b2ae3',
#    'location': {'address': '55 York Blvd',
#     'country': 'CA',
#     'cross_street': 'at James',
#     'formatted_address': '55 York Blvd (at James), Hamilton ON L8R 3K1',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 3K1',
#     'region': 'ON'},
#    'name': "Hamilton Farmers' Market",
#    'related_places': {'children': [{'fsq_id': '5d7bd06979bb820008173f0e',
#       'categories': [{'id': 13026,
#         'name': 'BBQ Joint',
#         'short_name': 'BBQ',
#         'plural_name': 'BBQ Joints',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#          'suffix': '.png'}}],
#       'name': 'Saltlick Smokehouse'},
#      {'fsq_id': '5688080b498ef6dccacdba77',
#       'categories': [{'id': 13145,
#         'name': 'Fast Food Restaurant',
#         'short_name': 'Fast Food',
#         'plural_name': 'Fast Food Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#          'suffix': '.png'}},
#        {'id': 13272,
#         'name': 'Ramen Restaurant',
#         'short_name': 'Ramen',
#         'plural_name': 'Ramen Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#          'suffix': '.png'}}],
#       'name': 'Eat Industries'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '51d2d6a9498e483fe7634ebf',
#    'categories': [{'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 403,
#    'geocodes': {'drop_off': {'latitude': 43.256701, 'longitude': -79.86911},
#     'main': {'latitude': 43.25672, 'longitude': -79.869105}},
#    'link': '/v3/places/51d2d6a9498e483fe7634ebf',
#    'location': {'address': '2 King St W',
#     'country': 'CA',
#     'cross_street': 'in Jackson Square',
#     'formatted_address': '2 King St W (in Jackson Square), Hamilton ON L8P 1A1',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1A1',
#     'region': 'ON'},
#    'name': 'Nations Fresh Food Market',
#    'related_places': {'parent': {'fsq_id': '4b628e9ff964a520474b2ae3',
#      'categories': [{'id': 17114,
#        'name': 'Shopping Mall',
#        'short_name': 'Mall',
#        'plural_name': 'Shopping Malls',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#         'suffix': '.png'}}],
#      'name': 'Jackson Square'}},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b5e5923f964a520b78a29e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13031,
#      'name': 'Burger Joint',
#      'short_name': 'Burgers',
#      'plural_name': 'Burger Joints',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}},
#     {'id': 13338,
#      'name': 'Seafood Restaurant',
#      'short_name': 'Seafood',
#      'plural_name': 'Seafood Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 409,
#    'geocodes': {'drop_off': {'latitude': 43.251943, 'longitude': -79.870017},
#     'main': {'latitude': 43.252066, 'longitude': -79.869987},
#     'roof': {'latitude': 43.252066, 'longitude': -79.869987}},
#    'link': '/v3/places/4b5e5923f964a520b78a29e3',
#    'location': {'address': '23 Augusta St',
#     'country': 'CA',
#     'cross_street': 'Hughson St.',
#     'formatted_address': '23 Augusta St (Hughson St.), Hamilton ON L8N 1P6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P6',
#     'region': 'ON'},
#    'name': 'The Ship',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b01f834f964a520e64622e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 420,
#    'geocodes': {'drop_off': {'latitude': 43.252037, 'longitude': -79.870397},
#     'main': {'latitude': 43.25192, 'longitude': -79.870426},
#     'roof': {'latitude': 43.25192, 'longitude': -79.870426}},
#    'link': '/v3/places/4b01f834f964a520e64622e3',
#    'location': {'address': '20 Augusta St',
#     'country': 'CA',
#     'cross_street': 'James St.',
#     'formatted_address': '20 Augusta St (James St.), Hamilton ON L8N 1P7',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P7',
#     'region': 'ON'},
#    'name': 'The Pheasant Plucker',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b6a4bc5f964a52024d12be3',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13134,
#      'name': 'Comfort Food Restaurant',
#      'short_name': 'Comfort Food',
#      'plural_name': 'Comfort Food Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 436,
#    'geocodes': {'main': {'latitude': 43.251462, 'longitude': -79.872017},
#     'roof': {'latitude': 43.251462, 'longitude': -79.872017}},
#    'link': '/v3/places/4b6a4bc5f964a52024d12be3',
#    'location': {'address': '1 Duke St',
#     'country': 'CA',
#     'cross_street': 'at James St. South',
#     'formatted_address': '1 Duke St (at James St. South), Hamilton ON L8P 1W9',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1W9',
#     'region': 'ON'},
#    'name': 'One Duke Restaurant & Lounge',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '591534a12aff31013acefff6',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13029,
#      'name': 'Brewery',
#      'short_name': 'Brewery',
#      'plural_name': 'Breweries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.25949, 'longitude': -79.867997},
#     'roof': {'latitude': 43.25949, 'longitude': -79.867997}},
#    'link': '/v3/places/591534a12aff31013acefff6',
#    'location': {'address': '107 James St N',
#     'country': 'CA',
#     'cross_street': 'at York Blvd',
#     'formatted_address': '107 James St N (at York Blvd), Hamilton ON L8R 2K6',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 2K6',
#     'region': 'ON'},
#    'name': 'Merit Brewing',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '56773b87498ee8858831bb66',
#    'categories': [{'id': 13033,
#      'name': 'Bubble Tea Shop',
#      'short_name': 'Bubble Tea',
#      'plural_name': 'Bubble Tea Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'}},
#     {'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 427,
#    'geocodes': {'main': {'latitude': 43.254333, 'longitude': -79.865966},
#     'roof': {'latitude': 43.254333, 'longitude': -79.865966}},
#    'link': '/v3/places/56773b87498ee8858831bb66',
#    'location': {'address': '96 Main St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '96 Main St E, Hamilton ON L8N 1G3',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1G3',
#     'region': 'ON'},
#    'name': 'Coco Fresh Tea & Juice',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.2557,
#      'longitude': -79.8711},
#     'radius': 1000}}}}

# %%
foursquarebiketracking=pd.DataFrame()
import json
for index, row in available_bikes.iterrows():
    ll = (row['Latitude'], row['Longitude'])
    foursquarebiketracking['Station Name']=row ['Station Name']
    response = get_nearby_venues(ll, 1000, None)
    foursquarebiketracking.loc[index,'newcolumn']=json.dumps(response)

# %%
foursquarebiketracking
# Out:
#          Station Name                                          newcolumn
# 0    Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 1    Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 2    Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 3    Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 4    Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# ..                ...                                                ...
# 139  Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 140  Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 141  Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 142  Cannon at Ottawa  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
# 143               NaN  {"results": [{"fsq_id": "4d93318162ad5481a9ec7...
#
# [144 rows x 2 columns]

# %%
venues=json.loads(foursquarebiketracking['newcolumn'][0])
flattenedvenue=pd.json_normalize(venues['results'])
flattenedvenue.head(2)
flattenedvenue.columns
# Out:
# Index(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'link',
#        'name', 'timezone', 'geocodes.main.latitude', 'geocodes.main.longitude',
#        'geocodes.roof.latitude', 'geocodes.roof.longitude', 'location.address',
#        'location.country', 'location.formatted_address', 'location.locality',
#        'location.postcode', 'location.region', 'location.cross_street',
#        'geocodes.drop_off.latitude', 'geocodes.drop_off.longitude',
#        'related_places.children', 'related_places.parent.fsq_id',
#        'related_places.parent.categories', 'related_places.parent.name'],
#       dtype='object')

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
flatteneddata=pd.DataFrame()
for index, row in foursquarebiketracking.iterrows():
    venues=json.loads (row['newcolumn'])
    flattenedvenue=pd.json_normalize (venues['results'])
    flattenedvenue['Station Name']=row['Station Name']
    flatteneddata=pd.concat([flatteneddata,flattenedvenue],ignore_index=True)

# %%
flatteneddata.head()
# Out:
#                      fsq_id  \
# 0  4d93318162ad5481a9ec7b4b
# 1  50a19225e4b035e940520491
# 2  55de230f498eecf46f6652a2
# 3  4b628f4bf964a5205a4b2ae3
# 4  51d2d6a9498e483fe7634ebf
#
#                                           categories chains   closed_bucket  \
# 0  [{'id': 10027, 'name': 'Museum', 'short_name':...     []  VeryLikelyOpen
# 1  [{'id': 13305, 'name': 'Burrito Restaurant', '...     []  VeryLikelyOpen
# 2  [{'id': 13306, 'name': 'Taco Restaurant', 'sho...     []  VeryLikelyOpen
# 3  [{'id': 17065, 'name': 'Farmers Market', 'shor...     []  VeryLikelyOpen
# 4  [{'id': 17069, 'name': 'Grocery Store', 'short...     []  VeryLikelyOpen
#
#    distance                                 link  \
# 0       172  /v3/places/4d93318162ad5481a9ec7b4b
# 1       320  /v3/places/50a19225e4b035e940520491
# 2       343  /v3/places/55de230f498eecf46f6652a2
# 3       395  /v3/places/4b628f4bf964a5205a4b2ae3
# 4       403  /v3/places/51d2d6a9498e483fe7634ebf
#
#                                   name         timezone  \
# 0  Whitehern Historic House and Garden  America/Toronto
# 1                         Burrito Boyz  America/Toronto
# 2                             The Mule  America/Toronto
# 3             Hamilton Farmers' Market  America/Toronto
# 4            Nations Fresh Food Market  America/Toronto
#
#    geocodes.main.latitude  geocodes.main.longitude  ...  location.postcode  \
# 0               43.254593               -79.872110  ...            L8P 1L3
# 1               43.255691               -79.867215  ...            L8N 1A6
# 2               43.257258               -79.867202  ...            L8R 1A2
# 3               43.259041               -79.870193  ...            L8R 3K1
# 4               43.256720               -79.869105  ...            L8P 1A1
#
#    location.region location.cross_street geocodes.drop_off.latitude  \
# 0               ON                   NaN                        NaN
# 1               ON                                              NaN
# 2               ON               Hughson                  43.257143
# 3               ON              at James                        NaN
# 4               ON     in Jackson Square                  43.256701
#
#   geocodes.drop_off.longitude  \
# 0                         NaN
# 1                         NaN
# 2                   -79.86724
# 3                         NaN
# 4                   -79.86911
#
#                              related_places.children  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'fsq_id': '5d7bd06979bb820008173f0e', 'categ...
# 4                                                NaN
#
#   related_places.parent.fsq_id  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4     4b628e9ff964a520474b2ae3
#
#                     related_places.parent.categories  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'id': 17114, 'name': 'Shopping Mall', 'short...
#
#   related_places.parent.name      Station Name
# 0                        NaN  Cannon at Ottawa
# 1                        NaN  Cannon at Ottawa
# 2                        NaN  Cannon at Ottawa
# 3                        NaN  Cannon at Ottawa
# 4             Jackson Square  Cannon at Ottawa
#
# [5 rows x 26 columns]

# %%
flatteneddata.to_csv('..\\data\\flattenedfoursquaredata.csv', index=False)

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import requests

# Define the function to get venues from Yelp
def get_venues_yelp(latitude, longitude, radius, api_key, categories=None):
    """
    Get venues from Yelp with a specified place type and coordinates.
    
    Args:
        latitude (float): Latitude for the query (must be combined with longitude).
        longitude (float): Longitude for the query (must be combined with latitude).
        radius (int): Search radius in meters.
        api_key (str): Yelp API key to use for the query.
        categories (str): Yelp-recognized place types. If not passed, no place_type will be specified. Separate ids with commas.
    
    Returns:
        response: Response object from the requests library.
    """
    # Create the URL
    url = "https://api.yelp.com/v3/businesses/search"
    
    # Create the parameters
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "radius": radius
    }
    
    # If categories are provided, add them to the parameters
    if categories:
        params["categories"] = categories
    
    # Create the headers with the correct authorization format
    headers = {
        "Authorization": f"Bearer {api_key}"
    }
    
    try:
        # Send the GET request to Yelp API
        response = requests.get(url, params=params, headers=headers)
        
        # Check the response status code
        print(response.status_code)
        
        # Return the response
        return response
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
latitude = 43.2557
longitude = -79.8711
radius = 1000  # in meters
api_key = "cRBYhL6JgM1_3z7dmW5PH1RvyG2HVcysOcqD7XtjH9Ag1tVrbBg82f-71Nox3xuzDbMlnhPSn9dGKXlKY1yTnrIxOn3iLdGvCEQira68_Y1ZfHnw__9WkHjMNRzuZXYx"
categories = "bikestations"  # Specify the Yelp-recognized place types (e.g., "bikestations")

# Call the function to get venues from Yelp
response = get_venues_yelp(latitude, longitude, radius, api_key, categories)

# Check the response status code
print(response.status_code)

# Print the response text
print(response.text)
# Out:
# 200
# 200
# {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw", "alias": "the-mule-hamilton", "name": "The Mule", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 181, "categories": [{"alias": "mexican", "title": "Mexican"}], "rating": 3.9, "coordinates": {"latitude": 43.25726, "longitude": -79.86713}, "transactions": [], "price": "$$", "location": {"address1": "41 King William Street", "address2": null, "address3": "", "city": "Hamilton", "zip_code": "L8R 1A2", "country": "CA", "state": "ON", "display_address": ["41 King William Street", "Hamilton, ON L8R 1A2", "Canada"]}, "phone": "+12893892555", "display_phone": "+1 289-389-2555", "distance": 355.3118981187424}, {"id": "bHecMQ85o3ayw1t9hRA90g", "alias": "the-french-hamilton", "name": "The French", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-french-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 99, "categories": [{"alias": "bistros", "title": "Bistros"}, {"alias": "french", "title": "French"}], "rating": 4.2, "coordinates": {"latitude": 43.25741, "longitude": -79.86748}, "transactions": [], "price": "$$$", "location": {"address1": "37 King William Street", "address2": "", "address3": null, "city": "Hamilton", "zip_code": "L8R 1A1", "country": "CA", "state": "ON", "display_address": ["37 King William Street", "Hamilton, ON L8R 1A1", "Canada"]}, "phone": "+19055283737", "display_phone": "+1 905-528-3737", "distance": 351.909786169935}, {"id": "752Fv2jKafftvoS3Twkqyg", "alias": "hambrgr-hamilton", "name": "Hambrgr", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 206, "categories": [{"alias": "burgers", "title": "Burgers"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.3, "coordinates": {"latitude": 43.25721, "longitude": -79.8669}, "transactions": [], "price": "$$", "location": {"address1": "49 King William Street", "address2": null, "address3": "", "city": "Hamilton", "zip_code": "L8R 1A2", "country": "CA", "state": "ON", "display_address": ["49 King William Street", "Hamilton, ON L8R 1A2", "Canada"]}, "phone": "+12893891212", "display_phone": "+1 289-389-1212", "distance": 377.3430524726985}, {"id": "xwVB61hW9rpyp6wALR4Apg", "alias": "berkeley-north-hamilton-2", "name": "Berkeley North", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 41, "categories": [{"alias": "bars", "title": "Bars"}, {"alias": "newcanadian", "title": "Canadian (New)"}], "rating": 4.3, "coordinates": {"latitude": 43.2574045478956, "longitude": -79.8677145254958}, "transactions": [], "price": "$$$", "location": {"address1": "31 King William Street", "address2": "", "address3": null, "city": "Hamilton", "zip_code": "L8R 1A1", "country": "CA", "state": "ON", "display_address": ["31 King William Street", "Hamilton, ON L8R 1A1", "Canada"]}, "phone": "+19055225858", "display_phone": "+1 905-522-5858", "distance": 333.3015970930127}, {"id": "wZr3xBFhGfYMY-mqwsQuNQ", "alias": "redchurch-cafe-gallery-hamilton", "name": "Redchurch Cafe + Gallery", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/qua9YE4kD7B3zl22UxtJLQ/o.jpg", "is_closed": fals ...

# %%
import pandas as pd

# %%
available_bikes_yelp2=pd.read_csv('..\\data\\available_bikes_yelp2.csv')

# %%
available_bikes_yelp2
# Out:
#               Station Name   Latitude  Longitude  Bikes Available
# 0             Hess at king  43.259126 -79.877212                8
# 1            Bayfront Park  43.269288 -79.871327                9
# 2          Bay at Strachan  43.267859 -79.867923                9
# 3          Bay at Mulberry  43.263198 -79.871803                4
# 4                City Hall  43.256132 -79.874499                2
# ..                     ...        ...        ...              ...
# 139  King William at James  43.257635 -79.868487                1
# 140        Westdale Aviary  43.264869 -79.907480                6
# 141       Hunter GO Centre  43.253330 -79.869533                3
# 142       Westdale Village  43.262015 -79.905088               11
# 143       Cannon at Ottawa  43.247565 -79.818050                5
#
# [144 rows x 4 columns]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=43.2557&longitude=-79.8711"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer cRBYhL6JgM1_3z7dmW5PH1RvyG2HVcysOcqD7XtjH9Ag1tVrbBg82f-71Nox3xuzDbMlnhPSn9dGKXlKY1yTnrIxOn3iLdGvCEQira68_Y1ZfHnw__9WkHjMNRzuZXYx"
}

response = requests.get(url, headers=headers)

print(response.text)

# Define category IDs for bike-related venues
bike_rental_category_id = '4e4c9077bd41f78e849722f9'  # Bike rental / bike shop category ID
# Out:
# {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw", "alias": "the-mule-hamilton", "name": "The Mule", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 181, "categories": [{"alias": "mexican", "title": "Mexican"}], "rating": 3.9, "coordinates": {"latitude": 43.25726, "longitude": -79.86713}, "transactions": [], "price": "$$", "location": {"address1": "41 King William Street", "address2": null, "address3": "", "city": "Hamilton", "zip_code": "L8R 1A2", "country": "CA", "state": "ON", "display_address": ["41 King William Street", "Hamilton, ON L8R 1A2", "Canada"]}, "phone": "+12893892555", "display_phone": "+1 289-389-2555", "distance": 355.3118981187424}, {"id": "bHecMQ85o3ayw1t9hRA90g", "alias": "the-french-hamilton", "name": "The French", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-french-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 99, "categories": [{"alias": "bistros", "title": "Bistros"}, {"alias": "french", "title": "French"}], "rating": 4.2, "coordinates": {"latitude": 43.25741, "longitude": -79.86748}, "transactions": [], "price": "$$$", "location": {"address1": "37 King William Street", "address2": "", "address3": null, "city": "Hamilton", "zip_code": "L8R 1A1", "country": "CA", "state": "ON", "display_address": ["37 King William Street", "Hamilton, ON L8R 1A1", "Canada"]}, "phone": "+19055283737", "display_phone": "+1 905-528-3737", "distance": 351.909786169935}, {"id": "9oIPWjU3DvtSdORv6I2toQ", "alias": "the-ship-hamilton", "name": "The Ship", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 207, "categories": [{"alias": "seafood", "title": "Seafood"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "burgers", "title": "Burgers"}], "rating": 4.1, "coordinates": {"latitude": 43.25215, "longitude": -79.87}, "transactions": [], "price": "$$", "location": {"address1": "23 Augusta Street", "address2": "", "address3": "", "city": "Hamilton", "zip_code": "L8N 1P6", "country": "CA", "state": "ON", "display_address": ["23 Augusta Street", "Hamilton, ON L8N 1P6", "Canada"]}, "phone": "+19055260792", "display_phone": "+1 905-526-0792", "distance": 404.5078559430542}, {"id": "752Fv2jKafftvoS3Twkqyg", "alias": "hambrgr-hamilton", "name": "Hambrgr", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg", "review_count": 206, "categories": [{"alias": "burgers", "title": "Burgers"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.3, "coordinates": {"latitude": 43.25721, "longitude": -79.8669}, "transactions": [], "price": "$$", "location": {"address1": "49 King William Street", "address2": null, "address3": "", "city": "Hamilton", "zip_code": "L8R 1A2", "country": "CA", "state": "ON", "display_address": ["49 King William Street", "Hamilton, ON L8R 1A2", "Canada"]}, "phone": "+12893891212", "display_phone": "+1 289-389-1212", "distance": 377.3430524726985}, {"id": "Q4oLgsU62VPR28pBm0vCXw", "alias": "bard\u014d-locke-street-hamilton", "name": "Bard\u014d Locke Street", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/t-G4g7Hq1wH4ZIWSB-a56g/o.jpg", "is_closed": false, "url": "https://www ...

# %%
# Function to query yelp API for venues near a given location
def get_nearby_venues(ll, radius, category_id):
    params = {
        # 'client_id': CLIENT_ID,
        # 'client_secret': CLIENT_SECRET,
        # 'v': VERSION,
        'll': ll,
        'radius': radius,
        'categoryId': category_id
    }
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer cRBYhL6JgM1_3z7dmW5PH1RvyG2HVcysOcqD7XtjH9Ag1tVrbBg82f-71Nox3xuzDbMlnhPSn9dGKXlKY1yTnrIxOn3iLdGvCEQira68_Y1ZfHnw__9WkHjMNRzuZXYx"
}
    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
       # return response.json()['response']['venues']
        return response.json()
    else:
        print(f'Error: {response.status_code} - {response.text}')
        return None

# %%
test=get_nearby_venues ((43.2557,-79.8711), 1000, None)

# %%
test
# Out:
# {'businesses': [{'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 181,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.25726, 'longitude': -79.86713},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['41 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893892555',
#    'display_phone': '+1 289-389-2555',
#    'distance': 355.3118981187424},
#   {'id': 'bHecMQ85o3ayw1t9hRA90g',
#    'alias': 'the-french-hamilton',
#    'name': 'The French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 99,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.25741, 'longitude': -79.86748},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '37 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['37 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055283737',
#    'display_phone': '+1 905-528-3737',
#    'distance': 351.909786169935},
#   {'id': '752Fv2jKafftvoS3Twkqyg',
#    'alias': 'hambrgr-hamilton',
#    'name': 'Hambrgr',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 206,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.25721, 'longitude': -79.8669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['49 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893891212',
#    'display_phone': '+1 289-389-1212',
#    'distance': 377.3430524726985},
#   {'id': 'xwVB61hW9rpyp6wALR4Apg',
#    'alias': 'berkeley-north-hamilton-2',
#    'name': 'Berkeley North',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 41,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.2574045478956,
#     'longitude': -79.8677145254958},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '31 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['31 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055225858',
#    'display_phone': '+1 905-522-5858',
#    'distance': 333.3015970930127},
#   {'id': 'wZr3xBFhGfYMY-mqwsQuNQ',
#    'alias': 'redchurch-cafe-gallery-hamilton',
#    'name': 'Redchurch Cafe + Gallery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qua9YE4kD7B3zl22UxtJLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redchurch-cafe-gallery-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 25,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25551, 'longitude': -79.86725},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['68 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19054070459',
#    'display_phone': '+1 905-407-0459',
#    'distance': 307.9264546303288},
#   {'id': '9oIPWjU3DvtSdORv6I2toQ',
#    'alias': 'the-ship-hamilton',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 207,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.25215, 'longitude': -79.87},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 Augusta Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1P6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['23 Augusta Street',
#      'Hamilton, ON L8N 1P6',
#      'Canada']},
#    'phone': '+19055260792',
#    'display_phone': '+1 905-526-0792',
#    'distance': 404.5078559430542},
#   {'id': 'Cg0WEknzjnguRylTcf1pEQ',
#    'alias': 'kenzo-hamilton',
#    'name': 'Kenzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rbxtzsWRIMnxlBbjL-AZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kenzo-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 25,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.256548097485,
#     'longitude': -79.8681968450546},
#    'transactions': [],
#    'location': {'address1': '21 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['21 King Street E', 'Hamilton, ON L8N 1A1', 'Canada']},
#    'phone': '+19055776666',
#    'display_phone': '+1 905-577-6666',
#    'distance': 253.31417087303663},
#   {'id': 'PAVNadox4HMXl-xdsjbjhg',
#    'alias': 'sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton',
#    'name': 'Sagarmatha Curry Palace  Authentic Indian & Nepalese Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sRLHpiBxJLpybfnuu0YROw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 41,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.25725, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055226999',
#    'display_phone': '+1 905-522-6999',
#    'distance': 367.90830605891756},
#   {'id': 'zldX2jhIDUBJzaEPYiSWUQ',
#    'alias': 'radius-hamilton',
#    'name': 'Radius',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9bd_uf5aVnJgtJOFA8BNpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radius-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 94,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 43.2523512, 'longitude': -79.8708333},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '151 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 2Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['151 James Street S',
#      'Hamilton, ON L8P 2Z5',
#      'Canada']},
#    'phone': '+19053931658',
#    'display_phone': '+1 905-393-1658',
#    'distance': 372.9950420410887},
#   {'id': '_Tl4-DH2ci_AVXq028__sg',
#    'alias': 'burrito-boyz-hamilton',
#    'name': 'Burrito Boyz',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p3C2_MKwb12bVWqaWjQLNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrito-boyz-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.2557373046875,
#     'longitude': -79.8669128417969},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '66 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['66 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19055292699',
#    'display_phone': '+1 905-529-2699',
#    'distance': 339.11593791205866},
#   {'id': 'TxrfCuyQThzsFUlcFqdqSw',
#    'alias': 'saint-james-espresso-bar-and-eatery-hamilton-2',
#    'name': 'Saint James Espresso Bar & Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-T6LAsL5n5Sa-EyW5vDq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-james-espresso-bar-and-eatery-hamilton-2?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 57,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.26098, 'longitude': -79.86693},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '170 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['170 James Street N',
#      'Hamilton, ON L8R 2L1',
#      'Canada']},
#    'phone': '+12893896565',
#    'display_phone': '+1 289-389-6565',
#    'distance': 679.8258228780344},
#   {'id': 'EGutBSi1dgdaJoLu-LdsTw',
#    'alias': 'august-8-hamilton',
#    'name': 'August 8',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HAndOnz4E-AIgQSaRJTwkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/august-8-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 125,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.25943, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Wilson Street',
#     'address2': 'Suite 12',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1 Wilson Street',
#      'Suite 12',
#      'Hamilton, ON L8R',
#      'Canada']},
#    'phone': '+19055243838',
#    'display_phone': '+1 905-524-3838',
#    'distance': 530.3493444139274},
#   {'id': 'OQvZPynueXmDp4H5fqWT_w',
#    'alias': 'undefined-hamilton',
#    'name': 'Undefined',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBmKwmOBRGvEjn62TIIoDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/undefined-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 8,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.25743, 'longitude': -79.86754},
#    'transactions': [],
#    'location': {'address1': '35 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['35 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19053938343',
#    'display_phone': '+1 905-393-8343',
#    'distance': 343.38385478879684},
#   {'id': 'XYZirPf2pYh4BAHb9GbtVA',
#    'alias': 'diplomat-hamilton',
#    'name': 'Diplomat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxoasGf51kBqhL3l4g-kSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diplomat-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 23,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.2572440040624,
#     'longitude': -79.8670820519328},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '43 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055234343',
#    'display_phone': '+1 905-523-4343',
#    'distance': 367.8996083353947},
#   {'id': 'F62oIPt7-CwuYHJ6vXp-HQ',
#    'alias': 'black-forest-inn-european-cuisine-hamilton',
#    'name': 'Black Forest Inn European Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EuO8QZ62njCuZr2_jrHMTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-inn-european-cuisine-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 54,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.2543558198212,
#     'longitude': -79.8615892650853},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '255 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1B9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['255 King Street E',
#      'Hamilton, ON L8N 1B9',
#      'Canada']},
#    'phone': '+19055283538',
#    'display_phone': '+1 905-528-3538',
#    'distance': 784.5893139940273},
#   {'id': 'GTAJyJuT_sE0byRLTdM5sA',
#    'alias': 'sapporo-japanese-restaurant-hamilton',
#    'name': 'Sapporo Japanese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aAgDdX7jF567YOHXJahCrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapporo-japanese-restaurant-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 93,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 43.25429, 'longitude': -79.866},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Main St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 Main St E', 'Hamilton, ON L8N 1G3', 'Canada']},
#    'phone': '+19055271668',
#    'display_phone': '+1 905-527-1668',
#    'distance': 434.6251594021986},
#   {'id': 'CH4A4Aa--t0A7bP1VfkMrA',
#    'alias': 'charred-chicken-hamilton',
#    'name': 'Charred Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/agEtNIDjFHSHuMTjDKhipQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charred-chicken-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 118,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.2627364, 'longitude': -79.8663839},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '244 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['244 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893960662',
#    'display_phone': '+1 289-396-0662',
#    'distance': 870.6422541964347},
#   {'id': 'YGPmtIFExK1InW_zafl4MA',
#    'alias': 'mesa-hamilton',
#    'name': 'Mesa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ITIIH6rxjRwjUwHNv1J8xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mesa-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 57,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.26306, 'longitude': -79.86645},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '255 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['255 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12892469696',
#    'display_phone': '+1 289-246-9696',
#    'distance': 902.7510456245989},
#   {'id': 'JPsfA7czh0PusUKqpduDUA',
#    'alias': 'ajio-sushi-hamilton',
#    'name': 'Ajio Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IhDS5NyrOffNTSXy0FFckQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajio-sushi-hamilton?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 41,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.21798, 'longitude': -79.74587},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '161 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1J6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['161 King Street E',
#      'Hamilton, ON L8R 1J6',
#      'Canada']},
#    'phone': '+19055268888',
#    'display_phone': '+1 905-526-8888',
#    'distance': 554.3762050519049},
#   {'id': 'RRnbO5NZq716CC8emwWedg',
#    'alias': 'mulberry-coffeehouse-hamilton-2',
#    'name': 'Mulberry Coffeehouse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MlTUR16niJX1HHEmrZrAvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mulberry-coffeehouse-hamilton-2?adjust_creative=Q2JJYlNhXlA-R_wRveKzeg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q2JJYlNhXlA-R_wRveKzeg',
#    'review_count': 76,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.26202675801636, 'longitude': -79.8669883},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '193 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['193 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+19059631365',
#    'display_phone': '+1 905-963-1365',
#    'distance': 778.3186724201186}],
#  'total': 222,
#  'region': {'center': {'longitude': -79.8711, 'latitude': 43.2557}}}

# %%
yelpbiketracking=pd.DataFrame()
import json
for index, row in available_bikes_yelp2.iterrows():
    ll = (row['Latitude'], row['Longitude'])
    yelpbiketracking['Station Name']=row ['Station Name']
    response = get_nearby_venues(ll, 1000, None)
    yelpbiketracking.loc[index,'newcolumn']=json.dumps(response)

# %%
yelpbiketracking
# Out:
#          Station Name                                          newcolumn
# 0    Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 1    Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 2    Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 3    Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 4    Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# ..                ...                                                ...
# 139  Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 140  Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 141  Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 142  Cannon at Ottawa  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
# 143               NaN  {"businesses": [{"id": "h2mI1wBIK1PyaNupaL58gw...
#
# [144 rows x 2 columns]

# %%
venues=json.loads(yelpbiketracking['newcolumn'][0])
flattenedvenue=pd.json_normalize(venues['businesses'])
flattenedvenue.head(2)
flattenedvenue.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address'],
#       dtype='object')

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
import json

# %%
flatteneddata=pd.DataFrame()
for index, row in yelpbiketracking.iterrows():
    venues=json.loads (row['newcolumn'])
    flattenedvenue=pd.json_normalize (venues['businesses'])
    flattenedvenue['Station Name']=row['Station Name']
    flatteneddata=pd.concat([flatteneddata,flattenedvenue],ignore_index=True)

# %%
flatteneddata.head()
# Out:
#                        id                            alias  \
# 0  h2mI1wBIK1PyaNupaL58gw                the-mule-hamilton
# 1  bHecMQ85o3ayw1t9hRA90g              the-french-hamilton
# 2  752Fv2jKafftvoS3Twkqyg                 hambrgr-hamilton
# 3  xwVB61hW9rpyp6wALR4Apg        berkeley-north-hamilton-2
# 4  wZr3xBFhGfYMY-mqwsQuNQ  redchurch-cafe-gallery-hamilton
#
#                        name  \
# 0                  The Mule
# 1                The French
# 2                   Hambrgr
# 3            Berkeley North
# 4  Redchurch Cafe + Gallery
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnn...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/Ha71df...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/3QVAoc...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/dR82Kl...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/qua9YE...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-mule-hamilton?adj...           181
# 1  https://www.yelp.com/biz/the-french-hamilton?a...            99
# 2  https://www.yelp.com/biz/hambrgr-hamilton?adju...           206
# 3  https://www.yelp.com/biz/berkeley-north-hamilt...            41
# 4  https://www.yelp.com/biz/redchurch-cafe-galler...            25
#
#                                           categories  rating transactions  \
# 0         [{'alias': 'mexican', 'title': 'Mexican'}]     3.9           []
# 1  [{'alias': 'bistros', 'title': 'Bistros'}, {'a...     4.2           []
# 2  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.3           []
# 3  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.3           []
# 4             [{'alias': 'cafes', 'title': 'Cafes'}]     4.5           []
#
#    ... coordinates.longitude       location.address1 location.address2  \
# 0  ...            -79.867130  41 King William Street              None
# 1  ...            -79.867480  37 King William Street
# 2  ...            -79.866900  49 King William Street              None
# 3  ...            -79.867715  31 King William Street
# 4  ...            -79.867250        68 King Street E
#
#    location.address3  location.city  location.zip_code location.country  \
# 0                          Hamilton            L8R 1A2               CA
# 1               None       Hamilton            L8R 1A1               CA
# 2                          Hamilton            L8R 1A2               CA
# 3               None       Hamilton            L8R 1A1               CA
# 4               None       Hamilton            L8N 1A6               CA
#
#   location.state                           location.display_address  \
# 0             ON  [41 King William Street, Hamilton, ON L8R 1A2,...
# 1             ON  [37 King William Street, Hamilton, ON L8R 1A1,...
# 2             ON  [49 King William Street, Hamilton, ON L8R 1A2,...
# 3             ON  [31 King William Street, Hamilton, ON L8R 1A1,...
# 4             ON   [68 King Street E, Hamilton, ON L8N 1A6, Canada]
#
#        Station Name
# 0  Cannon at Ottawa
# 1  Cannon at Ottawa
# 2  Cannon at Ottawa
# 3  Cannon at Ottawa
# 4  Cannon at Ottawa
#
# [5 rows x 25 columns]

# %%
flatteneddata.to_csv('..\\data\\flattenedYELPdata4.csv', index=False)

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %%
import pandas as pd

# Load the CSV file into a DataFrame
flattenedfoursquaredata = pd.read_csv('..\\data\\flattenedfoursquaredata.csv')

# Get the shape of the DataFrame
num_rows, num_columns = flattenedfoursquaredata.shape
print("Total rows:", num_rows)
print("Total columns:", num_columns)
# Out:
# Total rows: 1440
# Total columns: 26

# %%
import pandas as pd

# Load the CSV file into a DataFrame
flattenedYELPdata = pd.read_csv('..\\data\\flattenedYELPdata.csv')

# Get the shape of the DataFrame
num_rows, num_columns = flattenedYELPdata.shape
print("Total rows:", num_rows)
print("Total columns:", num_columns)
# Out:
# Total rows: 2880
# Total columns: 25

# %% [markdown]
# Based on the above query, we clearly see that the YELP data is much more robust - twice as much! we see that while the number of columns in both is almost the same (26 in foursquare and 25 in YELP), however, YELP has double the number of rows, 2880, whereas foursquare only 1440 rows.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
# Sort the DataFrame by the ratings column in descending order, then by name alphabetically
top_restaurants = flattenedYELPdata.sort_values(by=['rating', 'name'], ascending=[False, True])

# Select the top 10 restaurants
top_10_restaurants = top_restaurants.head(10)

# Display the top 10 restaurants
print("Top 10 restaurants:")
print(top_10_restaurants[['name', 'rating']])
# Out:
# Top 10 restaurants:
#                          name  rating
# 6    Redchurch Cafe + Gallery     4.5
# 26   Redchurch Cafe + Gallery     4.5
# 46   Redchurch Cafe + Gallery     4.5
# 66   Redchurch Cafe + Gallery     4.5
# 86   Redchurch Cafe + Gallery     4.5
# 106  Redchurch Cafe + Gallery     4.5
# 126  Redchurch Cafe + Gallery     4.5
# 146  Redchurch Cafe + Gallery     4.5
# 166  Redchurch Cafe + Gallery     4.5
# 186  Redchurch Cafe + Gallery     4.5
